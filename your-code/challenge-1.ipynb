# %% [markdown]
# # Challenge 1 - Tic Tac Toe
#
# In this lab you will perform deep learning analysis on a dataset of playing [Tic Tac Toe](https://en.wikipedia.org/wiki/Tic-tac-toe).
#
# There are 9 grids in Tic Tac Toe that are coded as the following picture shows:
#
# ![Tic Tac Toe Grids](tttboard.jpg)
#
# In the first 9 columns of the dataset you can find which marks (`x` or `o`) exist in the grids. If there is no mark in a certain grid, it is labeled as `b`. The last column is `class` which tells you whether Player X (who always moves first in Tic Tac Toe) wins in this configuration. Note that when `class` has the value `False`, it means either Player O wins the game or it ends up as a draw.

# %% [markdown]
# Follow the steps suggested below to conduct a neural network analysis using Tensorflow and Keras. You will build a deep learning model to predict whether Player X wins the game or not.
#
# ## Step 1: Data Engineering
#
# This dataset is almost in the ready-to-use state so you do not need to worry about missing values and so on. Still, some simple data engineering is needed.
#
# 1. Read `tic-tac-toe.csv` into a dataframe.
# 1. Inspect the dataset. Determine if the dataset is reliable by eyeballing the data.
# 1. Convert the categorical values to numeric in all columns.
# 1. Separate the inputs and output.
# 1. Normalize the input data.

# %%
# your code here
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.models import load_model

# %%
df=pd.read_csv('tic-tac-toe.csv')

# %%
df.head()
# Out:
#   TL TM TR ML MM MR BL BM BR  class
# 0  x  x  x  x  o  o  x  o  o   True
# 1  x  x  x  x  o  o  o  x  o   True
# 2  x  x  x  x  o  o  o  o  x   True
# 3  x  x  x  x  o  o  o  b  b   True
# 4  x  x  x  x  o  o  b  o  b   True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 958 entries, 0 to 957
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TL      958 non-null    object
#  1   TM      958 non-null    object
#  2   TR      958 non-null    object
#  3   ML      958 non-null    object
#  4   MM      958 non-null    object
#  5   MR      958 non-null    object
#  6   BL      958 non-null    object
#  7   BM      958 non-null    object
#  8   BR      958 non-null    object
#  9   class   958 non-null    bool
# dtypes: bool(1), object(9)
# memory usage: 68.4+ KB

# %%
print(df.nunique())
# Out:
# TL       3
# TM       3
# TR       3
# ML       3
# MM       3
# MR       3
# BL       3
# BM       3
# BR       3
# class    2
# dtype: int64

# %%
# Convert the categorical values to numeric using OneHotEncoder
X = df.drop('class', axis=1)
y = df['class']

encoder = OneHotEncoder(sparse_output=False)
X_encoded = encoder.fit_transform(X)

# Separate the inputs (X_encoded) and output (y)
# Convert target column to numeric as well
y = df['class'].astype(int)

# Normalize the input data
scaler = MinMaxScaler()
X_normalized = scaler.fit_transform(X_encoded)

# %% [markdown]
# ## Step 2: Build Neural Network
#
# To build the neural network, you can refer to your own codes you wrote while following the [Deep Learning with Python, TensorFlow, and Keras tutorial](https://www.youtube.com/watch?v=wQ8BIBpya2k) in the lesson. It's pretty similar to what you will be doing in this lab.
#
# 1. Split the training and test data.
# 1. Create a `Sequential` model.
# 1. Add several layers to your model. Make sure you use ReLU as the activation function for the middle layers. Use Softmax for the output layer because each output has a single lable and all the label probabilities add up to 1.
# 1. Compile the model using `adam` as the optimizer and `sparse_categorical_crossentropy` as the loss function. For metrics, use `accuracy` for now.
# 1. Fit the training data.
# 1. Evaluate your neural network model with the test data.
# 1. Save your model as `tic-tac-toe.model`.

# %%
# your code here

# Split into train/test sets
X_train, X_test, y_train, y_test = train_test_split(X_normalized, y, test_size=0.2, random_state=42)

# Build the model
model = Sequential()
model.add(Dense(32, activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dense(16, activation='relu'))
model.add(Dense(2, activation='softmax'))

# Compile the model
model.compile(
    optimizer=Adam(),
    loss=SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)

# Train the model
model.fit(X_train, y_train, epochs=20, batch_size=16, validation_split=0.1)

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f"\nTest accuracy: {accuracy:.4f}")

# Save the model
model.save("tic-tac-toe.keras")
# Out:
# Epoch 1/20
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6372 - loss: 0.6283 - val_accuracy: 0.7922 - val_loss: 0.5489
# Epoch 2/20
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6821 - loss: 0.5748 - val_accuracy: 0.7662 - val_loss: 0.5322
# Epoch 3/20
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7025 - loss: 0.5451 - val_accuracy: 0.7532 - val_loss: 0.5174
# Epoch 4/20
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7155 - loss: 0.5231 - val_accuracy: 0.7662 - val_loss: 0.5035
# Epoch 5/20
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7271 - loss: 0.5001 - val_accuracy: 0.7662 - val_loss: 0.4815
# Epoch 6/20
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7562 - loss: 0.4761 - val_accuracy: 0.7792 - val_loss: 0.4783
# Epoch 7/20
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7794 - loss: 0.4516 - val_accuracy: 0.7662 - val_loss: 0.4674
# Epoch 8/20
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7925 - loss: 0.4310 - val_accuracy: 0.7922 - val_loss: 0.4491
# Epoch 9/20
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8157 - loss: 0.4062 - val_accuracy: 0.7792 - val_loss: 0.4046
# Epoch 10/20
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8287 - loss: 0.3776 - val_accuracy: 0.7922 - val_loss: 0.3878
# Epoch 11/20
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8505 - loss: 0.3460 - val_accuracy: 0.8182 - val_loss: 0.3679
# Epoch 12/20
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8940 - loss: 0.3189 - val_accuracy: 0.8442 - val_loss: 0.3585
# Epoch 13/20
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9115 - loss: 0.2821 - val_accuracy: 0.8701 - val_loss: 0.3146
# Epoch 14/20
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9361 - loss: 0.2444 - val_accuracy: 0.9221 - val_loss: 0.2831
# Epoch 15/20
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9507 - loss: 0.2149 - val_accuracy: 0.8961 - val_loss: 0.2645
# Epoch 16/20
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9579 - loss: 0.1873 - val_accuracy: 0.9221 - val_loss: 0.2314
# Epoch 17/20
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9681 - loss: 0.1611 - val_accuracy: 0.9351 - val_loss: 0.1954
# Epoch 18/20
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9840 - loss: 0.1344 - val_accuracy: 0.9481 - val_loss: 0.1854
# Epoch 19/20
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9768 - loss: 0.1241 - val_accuracy: 0.9481 - val_loss: 0.1680
# Epoch 20/20
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9869 - loss: 0.1028 - val_accuracy: 0.9481 - val_loss: 0.1458
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9635 - loss: 0.1426
#
# Test accuracy: 0.9635

# %% [markdown]
# ## Step 3: Make Predictions
#
# Now load your saved model and use it to make predictions on a few random rows in the test dataset. Check if the predictions are correct.

# %%
# your code here

# Load the saved model
model = load_model("tic-tac-toe.keras")

# Pick a few random rows from the test set
num_samples = 5
indices = np.random.choice(len(X_test), size=num_samples, replace=False)
X_sample = X_test[indices]
y_true = y_test.iloc[indices]  # se y_test for um Series do pandas

# Make predictions
predictions = model.predict(X_sample)

# Convert softmax output to class labels (0 ou 1)
predicted_classes = np.argmax(predictions, axis=1)

# Show results
for i in range(num_samples):
    print(f"Sample {i+1}:")
    print(f"  True Label:      {y_true.iloc[i]}")
    print(f"  Predicted Label: {predicted_classes[i]}")
    print()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Sample 1:
#   True Label:      1
#   Predicted Label: 1
#
# Sample 2:
#   True Label:      1
#   Predicted Label: 1
#
# Sample 3:
#   True Label:      0
#   Predicted Label: 1
#
# Sample 4:
#   True Label:      1
#   Predicted Label: 1
#
# Sample 5:
#   True Label:      0
#   Predicted Label: 1

# %% [markdown]
# ## Step 4: Improve Your Model
#
# Did your model achieve low loss (<0.1) and high accuracy (>0.95)? If not, try to improve your model.
#
# But how? There are so many things you can play with in Tensorflow and in the next challenge you'll learn about these things. But in this challenge, let's just do a few things to see if they will help.
#
# * Add more layers to your model. If the data are complex you need more layers. But don't use more layers than you need. If adding more layers does not improve the model performance you don't need additional layers.
# * Adjust the learning rate when you compile the model. This means you will create a custom `tf.keras.optimizers.Adam` instance where you specify the learning rate you want. Then pass the instance to `model.compile` as the optimizer.
#     * `tf.keras.optimizers.Adam` [reference](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adam).
#     * Don't worry if you don't understand what the learning rate does. You'll learn about it in the next challenge.
# * Adjust the number of epochs when you fit the training data to the model. Your model performance continues to improve as you train more epochs. But eventually it will reach the ceiling and the performance will stay the same.

# %%
# your code here

# 1. Build a deeper model
model = Sequential([
    Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')
])

# 2. Use Adam optimizer with custom learning rate
optimizer = Adam(learning_rate=0.0005)

# 3. Compile the model
model.compile(optimizer=optimizer,
              loss='binary_crossentropy',
              metrics=['accuracy'])

# 4. Train the model with more epochs + validation
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_split=0.2,
    verbose=1
)

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f"\nTest accuracy: {accuracy:.4f}")
# Out:
# Epoch 1/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5490 - loss: 0.6830 - val_accuracy: 0.6818 - val_loss: 0.6328
# Epoch 2/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6471 - loss: 0.6272 - val_accuracy: 0.6818 - val_loss: 0.6008
# Epoch 3/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6683 - loss: 0.5924 - val_accuracy: 0.7338 - val_loss: 0.5724
# Epoch 4/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7304 - loss: 0.5579 - val_accuracy: 0.7727 - val_loss: 0.5437
# Epoch 5/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7533 - loss: 0.5163 - val_accuracy: 0.7727 - val_loss: 0.5261
# Epoch 6/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7696 - loss: 0.4805 - val_accuracy: 0.7792 - val_loss: 0.5072
# Epoch 7/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7876 - loss: 0.4480 - val_accuracy: 0.7922 - val_loss: 0.5032
# Epoch 8/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8154 - loss: 0.4127 - val_accuracy: 0.7792 - val_loss: 0.4867
# Epoch 9/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8415 - loss: 0.3754 - val_accuracy: 0.7922 - val_loss: 0.4551
# Epoch 10/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8693 - loss: 0.3345 - val_accuracy: 0.8247 - val_loss: 0.4268
# Epoch 11/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9069 - loss: 0.2931 - val_accuracy: 0.8247 - val_loss: 0.3952
# Epoch 12/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9248 - loss: 0.2498 - val_accuracy: 0.8247 - val_loss: 0.3776
# Epoch 13/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9379 - loss: 0.2209 - val_accuracy: 0.8571 - val_loss: 0.3220
# Epoch 14/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9641 - loss: 0.1837 - val_accuracy: 0.9091 - val_loss: 0.2796
# Epoch 15/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9722 - loss: 0.1476 - val_accuracy: 0.9156 - val_loss: 0.2549
# Epoch 16/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9804 - loss: 0.1282 - val_accuracy: 0.9091 - val_loss: 0.2128
# Epoch 17/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9853 - loss: 0.0988 - val_accuracy: 0.9416 - val_loss: 0.1923
# Epoch 18/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9886 - loss: 0.0818 - val_accuracy: 0.9416 - val_loss: 0.1782
# Epoch 19/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9886 - loss: 0.0692 - val_accuracy: 0.9481 - val_loss: 0.1693
# Epoch 20/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9902 - loss: 0.0592 - val_accuracy: 0.9481 - val_loss: 0.1582
# Epoch 21/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9918 - loss: 0.0498 - val_accuracy: 0.9481 - val_loss: 0.1511
# Epoch 22/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9935 - loss: 0.0413 - val_accuracy: 0.9610 - val_loss: 0.1350
# Epoch 23/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9951 - loss: 0.0360 - val_accuracy: 0.9481 - val_loss: 0.1393
# Epoch 24/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9951 - loss: 0.0340 - val_accuracy: 0.9610 - val_loss: 0.1250
# Epoch 25/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9967 - loss: 0.0269 - val_accuracy: 0.9545 - val_loss: 0.1209
# Epoch 26/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9984 - loss: 0.0227 - val_accuracy: 0.9610 - val_loss: 0.1168
# Epoch 27/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0192 - val_accuracy: 0.9675 - val_loss: 0.1220
# Epoch 28/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9984 - loss: 0.0174 - val_accuracy: 0.9545 - val_loss: 0.1146
# Epoch 29/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0149 - val_accuracy: 0.9610 - val_loss: 0.1122
# Epoch 30/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0134 - val_accuracy: 0.9545 - val_loss: 0.1076
# Epoch 31/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0115 - val_accuracy: 0.9545 - val_loss: 0.1063
# Epoch 32/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0101 - val_accuracy: 0.9545 - val_loss: 0.1069
# Epoch 33/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0096 - val_accuracy: 0.9545 - val_loss: 0.1009
# Epoch 34/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0086 - val_accuracy: 0.9675 - val_loss: 0.1082
# Epoch 35/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 0.9545 - val_loss: 0.1048
# Epoch 36/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 0.9545 - val_loss: 0.1036
# Epoch 37/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.9545 - val_loss: 0.0995
# Epoch 38/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 0.9545 - val_loss: 0.0998
# Epoch 39/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.9675 - val_loss: 0.1046
# Epoch 40/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.9610 - val_loss: 0.0985
# Epoch 41/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.9610 - val_loss: 0.0974
# Epoch 42/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.9610 - val_loss: 0.0974
# Epoch 43/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9610 - val_loss: 0.0998
# Epoch 44/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.9545 - val_loss: 0.0952
# Epoch 45/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.9610 - val_loss: 0.0952
# Epoch 46/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.9675 - val_loss: 0.1019
# Epoch 47/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.9610 - val_loss: 0.0962
# Epoch 48/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.9675 - val_loss: 0.0945
# Epoch 49/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.9675 - val_loss: 0.0945
# Epoch 50/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.9675 - val_loss: 0.0944
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9688 - loss: 0.0877
#
# Test accuracy: 0.9688

# %% [markdown]
# **Which approach(es) did you find helpful to improve your model performance?**

# %%
# your answer here
#To improve the model's performance, several changes were implemented. First, 
# additional hidden layers were added to increase the model's capacity to learn more complex patterns. 
# Then, the learning rate of the optimizer was manually adjusted using the Adam optimizer with a lower rate (0.0005) to ensure more stable training. 
# The number of training epochs was also increased to give the model more time to learn. 
# Lastly, a validation split was introduced during training to monitor performance and avoid overfitting. 
# These adjustments aimed to reduce loss and boost accuracy.
